# %%
import numpy
import matplotlib.pyplot as plt
x = numpy.linspace(0, 10, 100)
x
# Out:
# array([  0.        ,   0.1010101 ,   0.2020202 ,   0.3030303 ,
#          0.4040404 ,   0.50505051,   0.60606061,   0.70707071,
#          0.80808081,   0.90909091,   1.01010101,   1.11111111,
#          1.21212121,   1.31313131,   1.41414141,   1.51515152,
#          1.61616162,   1.71717172,   1.81818182,   1.91919192,
#          2.02020202,   2.12121212,   2.22222222,   2.32323232,
#          2.42424242,   2.52525253,   2.62626263,   2.72727273,
#          2.82828283,   2.92929293,   3.03030303,   3.13131313,
#          3.23232323,   3.33333333,   3.43434343,   3.53535354,
#          3.63636364,   3.73737374,   3.83838384,   3.93939394,
#          4.04040404,   4.14141414,   4.24242424,   4.34343434,
#          4.44444444,   4.54545455,   4.64646465,   4.74747475,
#          4.84848485,   4.94949495,   5.05050505,   5.15151515,
#          5.25252525,   5.35353535,   5.45454545,   5.55555556,
#          5.65656566,   5.75757576,   5.85858586,   5.95959596,
#          6.06060606,   6.16161616,   6.26262626,   6.36363636,
#          6.46464646,   6.56565657,   6.66666667,   6.76767677,
#          6.86868687,   6.96969697,   7.07070707,   7.17171717,
#          7.27272727,   7.37373737,   7.47474747,   7.57575758,
#          7.67676768,   7.77777778,   7.87878788,   7.97979798,
#          8.08080808,   8.18181818,   8.28282828,   8.38383838,
#          8.48484848,   8.58585859,   8.68686869,   8.78787879,
#          8.88888889,   8.98989899,   9.09090909,   9.19191919,
#          9.29292929,   9.39393939,   9.49494949,   9.5959596 ,
#          9.6969697 ,   9.7979798 ,   9.8989899 ,  10.        ])

# %%
obs = numpy.sin(x) + numpy.random.uniform(-0.1, 0.1, 100)

# %%
plt.plot(x, obs)

# %%
plt.show()

# %%
N = 1000
heads = numpy.zeros(N, dtype=int)

for i in range(N):
    heads[i] = numpy.random.random_integers(0,1,2).sum()

plt.stem(numpy.bincount(heads),marker='o')
plt.margins(0.1)

plt.show()
# Out:
# /Users/mac/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: DeprecationWarning: This function is deprecated. Please call randint(0, 1 + 1) instead

# %%
N = 10000
roll = numpy.zeros(N)
expectation = numpy.zeros(N)

for i in range(N):
    roll[i] = numpy.random.random_integers(1, 6)
for i in range(1, N):
    expectation[i] = numpy.mean(roll[0:i])
    
plt.plot(expectation)
plt.show()
# Out:
# /Users/mac/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: DeprecationWarning: This function is deprecated. Please call randint(1, 6 + 1) instead

# %%
obs = numpy.random.random_integers(100, 200, 1000)
obs.mean()
# Out:
# /Users/mac/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: This function is deprecated. Please call randint(100, 200 + 1) instead
#   if __name__ == '__main__':
# 150.68000000000001

# %%
obs.max()
# Out:
# 200

# %%
obs.min()
# Out:
# 100

# %%
obs.var()
# Out:
# 817.3456000000001

# %%
obs.std()
# Out:
# 28.589256723461702

# %%
rolls = numpy.random.random_integers(1, 6, 1000)
len(rolls)
# Out:
# /Users/mac/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 6 + 1) instead
#   if __name__ == '__main__':
# 1000

# %%
rolls.var()
# Out:
# 2.8217750000000006

# %%
X = numpy.random.uniform(100, 200, 1000)
a = -32
b = 16
Y = a * X + b
Y.std()
# Out:
# 935.76966483043498

# %%
abs(a) * X.std()
# Out:
# 935.76966483043498

# %%
X = numpy.random.random_integers(1, 100, 1000)
Y = numpy.random.random_integers(-300, -200, 1000)
X.mean()
# Out:
# /Users/mac/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 100 + 1) instead
#   if __name__ == '__main__':
# /Users/mac/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: DeprecationWarning: This function is deprecated. Please call randint(-300, -200 + 1) instead
#   from ipykernel import kernelapp as app
# 50.268999999999998

# %%
Y.mean()
# Out:
# -251.51400000000001

# %%
(X + Y).mean()
# Out:
# -201.245

# %%
numpy.random.random_integers(1, 100, 1000).var()
# Out:
# /Users/mac/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 100 + 1) instead
#   if __name__ == '__main__':
# 867.566956

# %%
numpy.random.random_integers(5, 500, 1000).var()
# Out:
# /Users/mac/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: This function is deprecated. Please call randint(5, 500 + 1) instead
#   if __name__ == '__main__':
# 21006.729675999999

# %%
5 * 5 * 867.566956
# Out:
# 21689.1739

# %%
import scipy.stats
dice = scipy.stats.randint(1, 7)
dice.rvs(1000).max()
# Out:
# 6

# %%
dice.pmf(4)
# Out:
# 0.16666666666666666

# %%
dice.cdf(4)
# Out:
# 0.66666666666666663

# %%
dice.cdf(4) - dice.cdf(1)
# Out:
# 0.5

# %%
tosses = numpy.random.choice(range(1,7))
tosses
# Out:
# 4

# %%
tosses = numpy.random.choice(range(1,7), 10000)
tosses
# Out:
# array([5, 1, 1, ..., 2, 4, 4])

# %%
tosses.mean()
# Out:
# 3.5125000000000002

# %%
numpy.median(tosses)
# Out:
# 4.0

# %%
len(numpy.where(tosses > 3)[0])
# Out:
# 5054

# %%
plt.hist(tosses, bins=6)
# Out:
# (array([ 1661.,  1637.,  1648.,  1714.,  1650.,  1690.]),
#  array([ 1.        ,  1.83333333,  2.66666667,  3.5       ,  4.33333333,
#          5.16666667,  6.        ]),
#  <a list of 6 Patch objects>)

# %%
plt.show()

# %%
u = scipy.stats.uniform(90, 10)
u

# %%
u.rvs(10)
# Out:
# array([ 91.45643861,  90.49714086,  98.33633197,  90.54237762,
#         98.28010543,  98.37293134,  96.79233787,  99.58588821,
#         94.26122353,  97.22314421])

# %%
u.rvs(1000).mean()
# Out:
# 95.081723018161455

# %%
(u.rvs(1000) < 92).sum() / 1000
# Out:
# 0.188

# %%
# Out:
# array([  3.98942280e-01,   3.96912251e-01,   3.90883931e-01,
#          3.81039507e-01,   3.67672436e-01,   3.51172916e-01,
#          3.32008980e-01,   3.10704486e-01,   2.87815442e-01,
#          2.63906165e-01,   2.39526659e-01,   2.15192461e-01,
#          1.91367915e-01,   1.68453513e-01,   1.46777638e-01,
#          1.26592680e-01,   1.08075230e-01,   9.13298239e-02,
#          7.63955298e-02,   6.32546052e-02,   5.18424154e-02,
#          4.20578610e-02,   3.37736510e-02,   2.68458845e-02,
#          2.11225477e-02,   1.64506763e-02,   1.26820683e-02,
#          9.67754721e-03,   7.30986545e-03,   5.46540492e-03,
#          4.04486639e-03,   2.96315857e-03,   2.14869355e-03,
#          1.54227900e-03,   1.09577221e-03,   7.70631042e-04,
#          5.36465244e-04,   3.69662637e-04,   2.52138056e-04,
#          1.70231576e-04,   1.13765535e-04,   7.52575687e-05,
#          4.92786192e-05,   3.19400618e-05,   2.04918821e-05,
#          1.30135811e-05,   8.18051551e-06,   5.09018302e-06,
#          3.13512599e-06,   1.91137312e-06,   1.15346608e-06,
#          6.89021948e-07,   4.07408570e-07,   2.38449349e-07,
#          1.38143672e-07,   7.92199799e-08,   4.49683896e-08,
#          2.52667171e-08,   1.40526807e-08,   7.73639102e-09,
#          4.21586333e-09,   2.27406833e-09,   1.21419760e-09,
#          6.41717835e-10,   3.35712664e-10,   1.73844203e-10,
#          8.91090019e-11,   4.52118024e-11,   2.27065387e-11,
#          1.12880502e-11,   5.55463849e-12,   2.70558725e-12,
#          1.30447621e-12,   6.22557774e-13,   2.94097974e-13,
#          1.37522348e-13,   6.36536635e-14,   2.91636853e-14,
#          1.32260536e-14,   5.93727315e-15,   2.63823001e-15,
#          1.16039850e-15,   5.05208371e-16,   2.17722239e-16,
#          9.28760896e-17,   3.92169602e-17,   1.63912778e-17,
#          6.78141882e-18,   2.77713633e-18,   1.12575195e-18,
#          4.51707285e-19,   1.79407401e-19,   7.05330220e-20,
#          2.74481769e-20,   1.05731256e-20,   4.03145816e-21,
#          1.52156250e-21,   5.68442201e-22,   2.10209192e-22,
#          7.69459863e-23])

# %%
test = scipy.stats.binom(n=100, p=0.1)
test.cdf(1)
# Out:
# 0.00032168805319411544

# %%
test.cdf(10)
# Out:
# 0.5831555122664922

# %%
test.ppf(0.05)
# Out:
# 5.0

# %%
wells = scipy.stats.binom(n=9, p=0.1)
wells.pmf(1)
# Out:
# 0.38742048899999959

# %%
N = 20000
wells = scipy.stats.binom(n=9, p=0.1)
trials = wells.rvs(N)
(trials == 1).sum() / float(N)
# Out:
# 0.39265

# %%
wells.cdf(1)
# Out:
# 0.77484097800000007

# %%
wells.pmf(1)
# Out:
# 0.38742048899999959

# %%
wells.pmf(0)
# Out:
# 0.38742048899999998

# %%
norm = scipy.stats.norm(0, 1)
norm.cdf(5)
# Out:
# 0.99999971334842808

# %%
norm.ppf(0.5)
# Out:
# 5.0

# %%
norm.ppf(0.01)
# Out:
# 2.6736521259591592

# %%
norm.isf(0.99)
# Out:
# 2.6736521259591592

# %%
norm.cdf(2.67)
# Out:
# 0.0099030755591642452

# %%
norm.cdf(5)
# Out:
# 0.5

# %%
norm.ppf(0.5)
# Out:
# 5.0

# %%
norm.cdf(5)
# Out:
# 0.5

# %%
norm.cdf(2) - norm.cdf(-2)
# Out:
# 0.95449973610364158

# %%
N = 10000
sim = numpy.zeros(N)
for i in range(N):
    sim[i] = numpy.random.uniform(30, 40, 100).mean()
plt.hist(sim, bins=20, alpha=0.75, normed=True)
# Out:
# (array([ 0.00672498,  0.02209635,  0.04611412,  0.12008886,  0.22672777,
#          0.43808416,  0.70708321,  0.96071088,  1.24315988,  1.34883808,
#          1.32385959,  1.1739887 ,  0.83485776,  0.564898  ,  0.29589895,
#          0.18733862,  0.06532834,  0.02593919,  0.01152853,  0.00384284]),
#  array([ 33.98656895,  34.09065854,  34.19474813,  34.29883772,
#          34.4029273 ,  34.50701689,  34.61110648,  34.71519607,
#          34.81928566,  34.92337524,  35.02746483,  35.13155442,
#          35.23564401,  35.3397336 ,  35.44382319,  35.54791277,
#          35.65200236,  35.75609195,  35.86018154,  35.96427113,  36.06836072]),
#  <a list of 20 Patch objects>)

# %%
plt.show()

# %%
lda = 25
obs = scipy.stats.expon.rvs(scale=1/float(lda), size=1000)
obs.mean(0)
# Out:
# 0.039025823983322924

# %%
obs.std()
# Out:
# 0.039103975411416407

# %%
1/float(lda)
# Out:
# 0.04

# %%
rate = 20.0
dt = 0.001
n = int(1.0/dt)
x = numpy.zeros(n)
x[numpy.random.rand(n) <= rate*dt] = 1
plt.figure(figsize=(6,2))
plt.vlines(numpy.nonzero(x)[0], 0, 1)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
plt.show()

# %%
y = numpy.cumsum(numpy.random.exponential(1.0/rate, size=int(rate)))
plt.figure(figsize=(6,2))
plt.vlines(y, 0, 1)
plt.xticks([])
plt.yticks([])
plt.show()
